# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
import pandas as pd
import numpy as np

data = pd.read_csv("C:/Users/ARNAB/Downloads/Student_Marks.csv")

data
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
X = data [['time_study']]
y = data ['Marks']

model = LinearRegression()
model.fit(X , y)

predicted_score = model.predict(X)

# evaluate

mae = mean_absolute_error(y , predicted_score)
mse = mean_squared_error (y , predicted_score)
rmse = np.sqrt(mse)

print("mean absolue error mae : " , mae)
print("mean squared error mse : " , mse)
print("root mean squared error rmse : " , mae)

new_prediction = model.predict([[7]])

print(f"predicted socre for 7 hours " , new_prediction)
# Out:
# mean absolue error mae :  3.8902784492899456
# mean squared error mse :  22.789030971957633
# root mean squared error rmse :  3.8902784492899456
# predicted socre for 7 hours  [41.04511106]
# C:\Users\ARNAB\AppData\Roaming\Python\Python310\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
